# %% [markdown]
# # pandas実習問題（その１）

# %% [markdown]
# ## 問題１
# ### pandasをインポートして別名をpdとしてください。

# %%
# pandasをインポート、別名をpdとする
# 実装
import pandas as pd

# %% [markdown]
# ## 問題２　データフレームの生成
# ### 下記のテーブルからデータフレームを生成して表示してください。
# ![pandas_ex_人口推移.PNG](data:image/png;base64,...)

# %%
# テーブルをディクショナリで定義
population ={ # 以下実装
             '青森市人口推移' : [ 298462,  296215,  293859,  290721,  287800],         # 青森市の情報
             '秋田市人口推移' : [ 319976,  318367,  315383,  313144,  310634],         # 秋田市の情報
             '盛岡市人口推移' : [ 295150,  295613,  295027,  293928,  292733],         # 盛岡市の情報
             '山形市人口推移' : [ 254089,  253335,  253832,  253267,  252095],         # 山形市の情報
             '仙台市人口推移' : [1063103, 1073242, 1082159, 1084674, 1085063],         # 仙台市の情報
             '福島市人口推移' : [ 284113,  283463,  283285,  294287,  292752]          # 福島市の情報
}   

# ディクショナリをDataFrame型に変換
# 実装
DF = pd.DataFrame(population)

# 表示
# 実装
DF
# Out:
#    青森市人口推移  秋田市人口推移  盛岡市人口推移  山形市人口推移  仙台市人口推移  福島市人口推移
# 0   298462   319976   295150   254089  1063103   284113
# 1   296215   318367   295613   253335  1073242   283463
# 2   293859   315383   295027   253832  1082159   283285
# 3   290721   313144   293928   253267  1084674   294287
# 4   287800   310634   292733   252095  1085063   292752

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題３
# ### 問題２で生成したデータフレームの型を表示してください。

# %%
# 問題２で生成したデータフレームの型を表示
# 実装
print(type(DF))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題４
# ### 問題２で生成したデータフレームの行数と列数を表示してください。

# %%
# 問題２で生成したデータフレームの行数と列数を表示
# 実装
DF.shape
print('行数 = ', len(DF.index))
print('列数 = ', len(DF.columns))
# Out:
# 行数 =  5
# 列数 =  6

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題５
# ### 問題２で作成したデータフレームにおいて、インデックスをデフォルトの整数から下記のテーブルとなるように年度に変更してください。
# ![pandas_ex_1_run4.PNG](data:image/png;base64,...)

# %%
# データフレームのインデックスを変更
# 実装
DF.index = ['平成２５年', '平成２６年', '平成２７年', '平成２８年', '平成２９年']

# 表示
# 実装
DF
# Out:
#        青森市人口推移  秋田市人口推移  盛岡市人口推移  山形市人口推移  仙台市人口推移  福島市人口推移
# 平成２５年   298462   319976   295150   254089  1063103   284113
# 平成２６年   296215   318367   295613   253335  1073242   283463
# 平成２７年   293859   315383   295027   253832  1082159   283285
# 平成２８年   290721   313144   293928   253267  1084674   294287
# 平成２９年   287800   310634   292733   252095  1085063   292752

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run5.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題６
# ### 問題５で変更したデータフレームの列名を下記のテーブルになるように変更してください。
# ![pandas_ex_人口推移_2.PNG](data:image/png;base64,...)

# %%
# データフレームの列名を変更
# 実装
DF.columns = [ '青森市人口推移（人）', '秋田市人口推移（人）', '盛岡市人口推移（人）', '山形市人口推移（人）', '仙台市人口推移（人）', '福島市人口推移（人）']
# データフレームを表示
# 実装
DF
# Out:
#        青森市人口推移（人）  秋田市人口推移（人）  盛岡市人口推移（人）  山形市人口推移（人）  仙台市人口推移（人）  福島市人口推移（人）
# 平成２５年      298462      319976      295150      254089     1063103      284113
# 平成２６年      296215      318367      295613      253335     1073242      283463
# 平成２７年      293859      315383      295027      253832     1082159      283285
# 平成２８年      290721      313144      293928      253267     1084674      294287
# 平成２９年      287800      310634      292733      252095     1085063      292752

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run6.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題７
# ### 問題６で生成したデータフレームのインデックスと列名を表示してください。

# %%
# データフレームのインデックスを表示
# 実装
print('インデックス = ', DF.columns)

# データフレームの列名を表示
# 実装
print('列名 = ', DF.index)
# Out:
# インデックス =  Index(['青森市人口推移（人）', '秋田市人口推移（人）', '盛岡市人口推移（人）', '山形市人口推移（人）', '仙台市人口推移（人）',
#        '福島市人口推移（人）'],
#       dtype='object')
# 列名 =  Index(['平成２５年', '平成２６年', '平成２７年', '平成２８年', '平成２９年'], dtype='object')

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run7.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題８
# ### 問題６の実行結果となるようにインデックスと列名をデータフレーム生成コンストラクタで指定して作成して表示してください。

# %%
# 各都市の人口推移を初期化
city_population = [   # 以下実装
             [ 298462, 319976, 295150, 254089, 1063103, 284113],         # 平成２５年の情報
             [ 296215, 318367, 295613, 253335, 1073242, 283463],         # 平成２６年の情報
             [ 293859, 315383, 295027, 253832, 1082159, 283285],         # 平成２７年の情報
             [ 290721, 313144, 293928, 253267, 1084674, 294287],         # 平成２８年の情報
             [ 287800, 310634, 292733, 252095, 1085063, 292752],         # 平成２９年の情報
]   
index = ['平成２５年', '平成２６年', '平成２７年', '平成２８年', '平成２９年']
columns = ['青森市人口推移（人）', '秋田市人口推移（人）', '盛岡市人口推移（人）', '山形市人口推移（人）', '仙台市人口推移（人）', '福島市人口推移（人）']

# インデックスと列名を指定してデータフレームを生成
# 実装
DF2 = pd.DataFrame(city_population, index, columns)

# 表示
# 実装
DF2
# Out:
#        青森市人口推移（人）  秋田市人口推移（人）  盛岡市人口推移（人）  山形市人口推移（人）  仙台市人口推移（人）  福島市人口推移（人）
# 平成２５年      298462      319976      295150      254089     1063103      284113
# 平成２６年      296215      318367      295613      253335     1073242      283463
# 平成２７年      293859      315383      295027      253832     1082159      283285
# 平成２８年      290721      313144      293928      253267     1084674      294287
# 平成２９年      287800      310634      292733      252095     1085063      292752

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_1_run8.PNG](data:image/png;base64,...)
