# %% [markdown]
# # Pandas実習問題（その２）

# %% [markdown]
# ### ※ 準備作業
# ### ⓵ドライブのマウント
# ### ⓶ディレクトリの作成
# ### ⓷作成したディレクトリへの移動
# ### ⓸csvファイル population_ja.csv、typhoon_18.csvのアップロード

# %% [markdown]
# ### Pandasのインポート

# %%
# pandasをインポートし、別名をpdとする
# 実装

# %% [markdown]
# ## 問題１
# ### アップロードした population_ja.csv を読み込み、データフレームに変換して、先頭の５行を表示してください。

# %%
# poplution_ja.csv を読み込む
# 実装

# 読み込んだデータ（データフレーム）の先頭５行を表示する
# 実装

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_2_run1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題２
# ### 問題１で作成したデータフレームの末尾５行を表示してください。

# %%
# データフレームの末尾５行を表示
# 実装

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_2_run1_2.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題３
# ### total列の先頭５行を表示してください。

# %%
# Total列の先頭５行を表示
# 実装

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_2_run3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題４
# ### Male列とFemale列の先頭５行を表示

# %%
# Male列とFemale列の先頭５行を表示
# 実装

# %% [markdown]
# ### ▶実行結果
# ![pandas_ex_2_run4.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題５
# ### 問題１で作成したデータフレームの列名を、以下のように変更して表示してください。
# ### year ⇒ 年度、Total ⇒ 全体、Male ⇒ 男性、Female ⇒ 女性

# %%
# 列名を変更
# 実装

# 表示
# 実装

# %% [markdown]
# ### ▶実行結果
#
# ![pandas_ex_2_run5.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題６
# ### アップロードした typhoon_18.csv を読み込んでデータフレームに変換して先頭の５行を表示してください。

# %%
# typhoon_18.csv を読み込む
# 実装

# 読み込んだデータ（データフレーム）の先頭５行を表示する
# 実装

# %% [markdown]
# ▶実行結果
#
# ![pandas_ex_2_run6.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 問題７
# ### 順位、市町村、降水量(mm)列の先頭５行を表示してください。

# %%
# 順位、市町村、降水量(mm)列の先頭５行を表示
# 実装

# %% [markdown]
# ### ▶実行結果
#
# ![pandas_ex_2_run7.PNG](data:image/png;base64,...)
